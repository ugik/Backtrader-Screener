# %%
import requests
import json
from datetime import datetime, timedelta
cookies = {'sessionid': 'zw53stv84dn2am47ag5prl0uvh31joz3'}
ETFs =['SPY', 'SH', 'VXX', 'EEM', 'QQQ', 'PSQ', 'XLF', 'GDX', 'HYG', 'EFA', 'IAU', 'XOP', 'IWM', 'FXI', 'SLV', 'USO', 'XLE', 'IEMG', 'AMLP', 'EWZ', 'XLK', 'XLI', 'VWO', 'GLD', 'XLP', 'JNK', 'EWJ', 'XLU', 'VEA', 'IEFA', 'XLV', 'PFF', 'VIXY', 'TLT', 'GDXJ', 'LQD', 'XLB', 'BKLN', 'XLY', 'SMH', 'OIH', 'ASHR', 'RSX', 'MCHI', 'VTI', 'EWH', 'SPLV', 'KRE', 'IVV', 'DIA', 'IEF', 'EZU', 'EWT', 'SPDW', 'VOO', 'SCHF', 'EWY', 'MYY', 'DOG', 'EUM']
for ticker in ETFs:
    period = 365
    endDate = datetime.today().strftime('%Y-%m-%d')
    startDate = (datetime.today() - timedelta(days=period)).strftime('%Y-%m-%d')
    url = "https://api.tiingo.com/tiingo/daily/%s/prices?startDate=%s&endDate=%s" % (ticker, startDate, endDate)

    response = requests.get(url, cookies=cookies)
    jsonData = {}
    if response.status_code == 200:
        jsonData = json.loads(response.text)
        if jsonData:
            filename = '%s_%s_%s.txt' % (ticker, startDate, endDate)
            f = open(filename, "w")
            f.write('Date,Open,High,Low,Close,Adj Close,Volume\n')
            for data in jsonData:

                f.write(data['date'][0:10] +',' +str(data['open']) +',' +str(data['high']) +',' +str(data['low'])  
                                           +',' +str(data['close']) +',' +str(data['adjClose']) +',' +str(data['volume']) +'\n')

            f.close()
            print ('file: %s created' % filename)
# Out:
# file: SPY_2019-02-26_2020-02-26.txt created
# file: SH_2019-02-26_2020-02-26.txt created
# file: VXX_2019-02-26_2020-02-26.txt created
# file: EEM_2019-02-26_2020-02-26.txt created
# file: QQQ_2019-02-26_2020-02-26.txt created
# file: PSQ_2019-02-26_2020-02-26.txt created
# file: XLF_2019-02-26_2020-02-26.txt created
# file: GDX_2019-02-26_2020-02-26.txt created
# file: HYG_2019-02-26_2020-02-26.txt created
# file: EFA_2019-02-26_2020-02-26.txt created
# file: IAU_2019-02-26_2020-02-26.txt created
# file: XOP_2019-02-26_2020-02-26.txt created
# file: IWM_2019-02-26_2020-02-26.txt created
# file: FXI_2019-02-26_2020-02-26.txt created
# file: SLV_2019-02-26_2020-02-26.txt created
# file: USO_2019-02-26_2020-02-26.txt created
# file: XLE_2019-02-26_2020-02-26.txt created
# file: IEMG_2019-02-26_2020-02-26.txt created
# file: AMLP_2019-02-26_2020-02-26.txt created
# file: EWZ_2019-02-26_2020-02-26.txt created
# file: XLK_2019-02-26_2020-02-26.txt created
# file: XLI_2019-02-26_2020-02-26.txt created
# file: VWO_2019-02-26_2020-02-26.txt created
# file: GLD_2019-02-26_2020-02-26.txt created
# file: XLP_2019-02-26_2020-02-26.txt created
# file: JNK_2019-02-26_2020-02-26.txt created
# file: EWJ_2019-02-26_2020-02-26.txt created
# file: XLU_2019-02-26_2020-02-26.txt created
# file: VEA_2019-02-26_2020-02-26.txt created
# file: IEFA_2019-02-26_2020-02-26.txt created
# file: XLV_2019-02-26_2020-02-26.txt created
# file: PFF_2019-02-26_2020-02-26.txt created
# file: VIXY_2019-02-26_2020-02-26.txt created
# file: TLT_2019-02-26_2020-02-26.txt created
# file: GDXJ_2019-02-26_2020-02-26.txt created
# file: LQD_2019-02-26_2020-02-26.txt created
# file: XLB_2019-02-26_2020-02-26.txt created
# file: BKLN_2019-02-26_2020-02-26.txt created
# file: XLY_2019-02-26_2020-02-26.txt created
# file: SMH_2019-02-26_2020-02-26.txt created
# file: OIH_2019-02-26_2020-02-26.txt created
# file: ASHR_2019-02-26_2020-02-26.txt created
# file: RSX_2019-02-26_2020-02-26.txt created
# file: MCHI_2019-02-26_2020-02-26.txt created
# file: VTI_2019-02-26_2020-02-26.txt created
# file: EWH_2019-02-26_2020-02-26.txt created
# file: SPLV_2019-02-26_2020-02-26.txt created
# file: KRE_2019-02-26_2020-02-26.txt created
# file: IVV_2019-02-26_2020-02-26.txt created
# file: DIA_2019-02-26_2020-02-26.txt created
# file: IEF_2019-02-26_2020-02-26.txt created
# file: EZU_2019-02-26_2020-02-26.txt created
# file: EWT_2019-02-26_2020-02-26.txt created
# file: SPDW_2019-02-26_2020-02-26.txt created
# file: VOO_2019-02-26_2020-02-26.txt created
# file: SCHF_2019-02-26_2020-02-26.txt created
# file: EWY_2019-02-26_2020-02-26.txt created
# file: MYY_2019-02-26_2020-02-26.txt created
# file: DOG_2019-02-26_2020-02-26.txt created
# file: EUM_2019-02-26_2020-02-26.txt created
